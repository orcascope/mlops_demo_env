# %%
from google.protobuf.json_format import MessageToDict
import tensorflow_data_validation as tfdv
training_stats = tfdv.generate_statistics_from_csv("training_data.csv")
serving_stats = tfdv.generate_statistics_from_csv("serving_data.csv")
tfdv.visualize_statistics(training_stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %% [markdown]
# ##### Infer the schema using the DatasetFeatureStatisticsList

# %%
training_schema = tfdv.infer_schema(training_stats, max_string_domain_size = 1000000)

# Non Null values of City to be 99%
city_feature = tfdv.get_feature(training_schema, 'city')
city_feature.presence.min_fraction=.99

#Setup L-infty thresold on product
product_feature = tfdv.get_feature(training_schema, 'product')
product_feature.drift_comparator.infinity_norm.threshold=0.01

#Setup Range of expected values for amount, integer domain
amount_feature = tfdv.get_feature(training_schema, 'amount')
amount_feature.value_count.min=1
amount_feature.value_count.max=10

#Setup a max value on int column, to showcase out of range values
id_feature = tfdv.get_feature(training_schema, 'id')
id_feature.int_domain.max = 10

# Relax the min fraction of values that must come from the domain for feature period_key.
period_key_feature = tfdv.get_feature(training_schema, 'period_key')
period_key_feature.distribution_constraints.min_domain_mass = 0
product_feature.distribution_constraints.min_domain_mass = 0
city_feature.distribution_constraints.min_domain_mass = 0

period_key_feature.int_domain

#Save the schema for future consumption. But the schema object is alreay updated in memory.
tfdv.write_schema_text(training_schema, 'training_schema_fixed')

# %%
drift_anomalies = tfdv.validate_statistics(statistics=serving_stats, schema=training_schema, previous_statistics=training_stats)
tfdv.display_anomalies(drift_anomalies)
# Out:
#                                       Anomaly short description  \
# Feature name
# 'city'                                           Column dropped
# 'product'     High Linfty distance between current and previous
# 'supplier'                             Unexpected string values
# 'id'                                        Out-of-range values
# 'country'                                        Column dropped
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Anomaly long description
# Feature name
# 'city'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             The feature was present in fewer examples than expected: minimum fraction = 0.990000, actual = 0.970000
# 'product'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                The Linfty distance between current and previous is 0.12381 (up to six significant digits), above the threshold 0.01. The feature value with maximum difference is: Acetaminophen
# 'supplier'    Examples contain values missing from the schema: ALK-Abello, Inc. (~1%), AMI Cosmetic Co.,Ltd. (~1%), Actavis Inc. (~1%), Advanced Generic Corporation (~1%), Ajou Medics Co., Ltd (~1%), Allergy Laboratories, Inc. (~1%), American Regent, Inc. (~2%), Antigen Laboratories, Inc. (~1%), Arbonne International, LLC (~1%), AuroMedics Pharma LLC (~1%), Aurobindo Pharma Limited (~1%), B. Braun Medical Inc. (~1%), Camber Pharmaceuticals, Inc. (~1%), Cardinal Health (Leader) (~1%), Claris Lifesciences Inc. (~1%), Clinical Solutions Wholesale (~1%), Core Brands, Inc. (~1%), Cresson (~1%), DZA Brands LLC (~1%), Dispensing Solutions, Inc. (~1%), Dr. Fresh, Inc. (~1%), Ferring Pharmaceuticals Inc. (~1%), G.D. Searle LLC Division of Pfizer Inc (~1%), GOJO Industries, Inc. (~1%), Have and Be Co., Ltd. (~1%), Inel Cosmetics Co., Ltd. (~1%), JAFRA COSMETICS INTERNATIONAL (~1%), Janssen Pharmaceuticals, Inc. (~1%), Jubilant HollisterStier LLC (~2%), KAISER FOUNDATION HOSPITALS (~1%), L\'Oreal USA Products Inc (~1%), Laboratoires Boiron (~1%), Liddell Laboratories, Inc. (~1%), Marathon Pharmaceuticals, LLC (~1%), MedVantx, Inc. (~1%), Merck Sharp & Dohme Corp. (~1%), MineralHouse Corporation (~1%), Modern Welding Company, Inc. (~1%), Native Remedies, LLC (~1%), OMP, INC. (~1%), PETNET Solutions, Inc. (~1%), Paddock Laboratories, LLC (~1%), Parfums Christian Dior (~1%), Performance Health LLC. (~1%), Pfizer Laboratories Div Pfizer Inc (~1%), Preferred Pharmaceuticals, Inc (~1%), Preferred Pharmaceuticals, Inc. (~1%), Procter & Gamble Manufacturing Company (~1%), Procter and Gamble Manufacturing Company (~1%), Proficient Rx LP (~1%), Qualitest Pharmaceuticals (~1%), Ranbaxy Pharmaceuticals Inc. (~1%), SDA Laboratories, Inc. (~1%), SMART SENSE (Kmart) (~1%), Safeway Inc. (~1%), Safeway, Inc. (~1%), Sage Products LLC (~1%), Shanghai Yinjing Medical Supplies Co., Ltd. (~1%), Shopko Stores Operating Co., LLC (~1%), Speer Laboratories, LLC (~1%), Supervalu Inc (~2%), Supervalu Inc. (~1%), Target Corporation (~1%), Terumo Corporation (~1%), The Harvard Drug Group, LLC (~1%), The Procter & Gamble Manufacturing Company (~1%), Topco Associates LLC (~1%), Unit Dose Services (~1%), Uriel Pharmacy Inc. (~1%), Ventura Corporation LTD (~1%), Western Family Foods Inc (~1%), Wockhardt Limited (~2%), sanofi-aventis U.S. LLC (~1%).
# 'id'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Unexpectedly large value: 100.
# 'country'                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Column is completely missing

# %%
#on a per example basis - yet to fully understand
options = tfdv.StatsOptions(schema=training_schema)
anomalous_example_stats = tfdv.validate_examples_in_csv(
   data_location="serving_data.csv", stats_options=options)
print(anomalous_example_stats)
# Out:
# datasets {
#   name: "supplier_ENUM_TYPE_UNEXPECTED_STRING_VALUES"
#   num_examples: 77
#   features {
#     num_stats {
#       common_stats {
#         num_non_missing: 77
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 77
#       }
#       mean: 49.83116883116883
#       std_dev: 28.71508160567974
#       min: 1.0
#       median: 52.0
#       max: 100.0
#       histograms {
#         buckets {
#           low_value: 1.0
#           high_value: 10.9
#           sample_count: 8.0003
#         }
#         buckets {
#           low_value: 10.9
#           high_value: 20.8
#           sample_count: 7.969499999999999
#         }
#         buckets {
#           low_value: 20.8
#           high_value: 30.700000000000003
#           sample_count: 8.031099999999999
#         }
#         buckets {
#           low_value: 30.700000000000003
#           high_value: 40.6
#           sample_count: 6.994166666666666
#         }
#         buckets {
#           low_value: 40.6
#           high_value: 50.5
#           sample_count: 6.029100000000001
#         }
#         buckets {
#           low_value: 50.5
#           high_value: 60.400000000000006
#           sample_count: 9.976633333333334
#         }
#         buckets {
#           low_value: 60.400000000000006
#           high_value: 70.3
#           sample_count: 8.0003
#         }
#         buckets {
#           low_value: 70.3
#           high_value: 80.2
#           sample_count: 8.0003
#         }
#         buckets {
#           low_value: 80.2
#           high_value: 90.10000000000001
#           sample_count: 6.0445
#         }
#         buckets {
#           low_value: 90.10000000000001
#           high_value: 100.0
#           sample_count: 7.954099999999999
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 1.0
#           high_value: 10.0
#           sample_count: 7.7
#         }
#         buckets {
#           low_value: 10.0
#           high_value: 20.0
#           sample_count: 7.7
#         }
#         buckets {
#           low_value: 20.0
#           high_value: 30.0
#           sample_count: 7.7
#         }
#         buckets {
#           low_value: 30.0
#           high_value: 39.0
#           sample_count: 7.7
#         }
#         buckets {
#           low_value: 39.0
#           high_value: 52.0
#           sample_count: 7.7
#         }
#         buckets {
#           low_value: 52.0
#           high_value: 60.0
#           sample_count: 7.7
#         }
#         buckets {
#           low_value: 60.0
#           high_value: 69.0
#           sample_count: 7.7
#         }
#         buckets {
#           low_value: 69.0
#           high_value: 79.0
#           sample_count: 7.7
#         }
#         buckets {
#           low_value: 79.0
#           high_value: 91.0
#           sample_count: 7.7
#         }
#         buckets {
#           low_value: 91.0
#           high_value: 100.0
#           sample_count: 7.7
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "id"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 74
#         num_missing: 3
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.4
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.4
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 74
#       }
#       unique: 74
#       top_values {
#         value: "Zapatero"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Yongyang"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Yantang"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Yalag\303\274ina"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Xin\342\200\231an"
#         frequency: 1.0
#       }
#       top_values {
#         value: "W\304\201ling"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Wonorejo"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Watari"
#         frequency: 1.0
#       }
#       top_values {
#         value: "V\303\244ster\303\245s"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Verkhnya Rozhanka"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Velyka Bahachka"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Uluarang"
#         frequency: 1.0
#       }
#       top_values {
#         value: "T\303\251ra"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Tiet\303\252"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Th\341\273\213 Tr\341\272\245n T\303\240 L\303\271ng"
#         frequency: 1.0
#       }
#       top_values {
#         value: "S\304\205sp\303\263w"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Susaki"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Socabaya"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Smolenskaya"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Shabo"
#         frequency: 1.0
#       }
#       avg_length: 9.256756782531738
#       rank_histogram {
#         buckets {
#           label: "Zapatero"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "Yongyang"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "Yantang"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 3
#           high_rank: 3
#           label: "Yalag\303\274ina"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 4
#           high_rank: 4
#           label: "Xin\342\200\231an"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 5
#           high_rank: 5
#           label: "W\304\201ling"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 6
#           high_rank: 6
#           label: "Wonorejo"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7
#           high_rank: 7
#           label: "Watari"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 8
#           high_rank: 8
#           label: "V\303\244ster\303\245s"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 9
#           high_rank: 9
#           label: "Verkhnya Rozhanka"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 10
#           high_rank: 10
#           label: "Velyka Bahachka"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 11
#           high_rank: 11
#           label: "Uluarang"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 12
#           high_rank: 12
#           label: "T\303\251ra"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 13
#           high_rank: 13
#           label: "Tiet\303\252"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 14
#           high_rank: 14
#           label: "Th\341\273\213 Tr\341\272\245n T\303\240 L\303\271ng"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 15
#           high_rank: 15
#           label: "S\304\205sp\303\263w"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 16
#           high_rank: 16
#           label: "Susaki"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 17
#           high_rank: 17
#           label: "Socabaya"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 18
#           high_rank: 18
#           label: "Smolenskaya"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 19
#           high_rank: 19
#           label: "Shabo"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 20
#           high_rank: 20
#           label: "Saxin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 21
#           high_rank: 21
#           label: "Sarirejo Satu"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 22
#           high_rank: 22
#           label: "San Jos\303\251 de los Remates"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 23
#           high_rank: 23
#           label: "San Isidro"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 24
#           high_rank: 24
#           label: "San Andr\303\251s"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 25
#           high_rank: 25
#           label: "R\303\244ttvik"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 26
#           high_rank: 26
#           label: "Ryazan\342\200\231"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 27
#           high_rank: 27
#           label: "Roissy Charles-de-Gaulle"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 28
#           high_rank: 28
#           label: "Rochester"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 29
#           high_rank: 29
#           label: "Richmond"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 30
#           high_rank: 30
#           label: "Reshetnikovo"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 31
#           high_rank: 31
#           label: "Reshetikha"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 32
#           high_rank: 32
#           label: "Potongan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 33
#           high_rank: 33
#           label: "Pofadder"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 34
#           high_rank: 34
#           label: "Pionerskiy"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 35
#           high_rank: 35
#           label: "Paris 17"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 36
#           high_rank: 36
#           label: "Palestina"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 37
#           high_rank: 37
#           label: "Novi Slankamen"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 38
#           high_rank: 38
#           label: "Moxi"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 39
#           high_rank: 39
#           label: "Morbatoh"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 40
#           high_rank: 40
#           label: "Montlu\303\247on"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 41
#           high_rank: 41
#           label: "Micheng"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 42
#           high_rank: 42
#           label: "Merlo"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 43
#           high_rank: 43
#           label: "Ma\305\202a Wie\305\233"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 44
#           high_rank: 44
#           label: "Mangere"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 45
#           high_rank: 45
#           label: "Magepanda"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 46
#           high_rank: 46
#           label: "Limoges"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 47
#           high_rank: 47
#           label: "Liberia"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 48
#           high_rank: 48
#           label: "Labuhantanggabesar"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 49
#           high_rank: 49
#           label: "Konyshevka"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 50
#           high_rank: 50
#           label: "Kochetok"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 51
#           high_rank: 51
#           label: "Khuzd\304\201r"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 52
#           high_rank: 52
#           label: "Kende"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 53
#           high_rank: 53
#           label: "Karagandy"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 54
#           high_rank: 54
#           label: "Jinniu"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 55
#           high_rank: 55
#           label: "Ituzaing\303\263"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 56
#           high_rank: 56
#           label: "Houten"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 57
#           high_rank: 57
#           label: "Hamburg"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 58
#           high_rank: 58
#           label: "Guyi"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 59
#           high_rank: 59
#           label: "Gununganyar"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 60
#           high_rank: 60
#           label: "Gorbunki"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 61
#           high_rank: 61
#           label: "Far\304\253m\304\201n"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 62
#           high_rank: 62
#           label: "Escada"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 63
#           high_rank: 63
#           label: "Entre Rios"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 64
#           high_rank: 64
#           label: "Dolno Pal\304\215i\305\241te"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 65
#           high_rank: 65
#           label: "Dait\305\215ch\305\215"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 66
#           high_rank: 66
#           label: "Changning"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 67
#           high_rank: 67
#           label: "Cadiz"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 68
#           high_rank: 68
#           label: "Bia\305\202acz\303\263w"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 69
#           high_rank: 69
#           label: "Berb\303\251rati"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 70
#           high_rank: 70
#           label: "Babice"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 71
#           high_rank: 71
#           label: "Athlone"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 72
#           high_rank: 72
#           label: "Al Q\305\253\305\237\304\253yah"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 73
#           high_rank: 73
#           label: "Airuk"
#           sample_count: 1.0
#         }
#       }
#     }
#     path {
#       step: "city"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 69
#         num_missing: 8
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6.9
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 6.9
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 69
#       }
#       unique: 64
#       top_values {
#         value: "DOCUSATE SODIUM"
#         frequency: 3.0
#       }
#       top_values {
#         value: "Trace Elements 4"
#         frequency: 2.0
#       }
#       top_values {
#         value: "Sodium Fluoride"
#         frequency: 2.0
#       }
#       top_values {
#         value: "Octinoxate and Titanium Dioxide"
#         frequency: 2.0
#       }
#       top_values {
#         value: "topiramate"
#         frequency: 1.0
#       }
#       top_values {
#         value: "robinia pseudoacacia pollen"
#         frequency: 1.0
#       }
#       top_values {
#         value: "prazosin hydrochloride"
#         frequency: 1.0
#       }
#       top_values {
#         value: "leflunomide"
#         frequency: 1.0
#       }
#       top_values {
#         value: "disopyramide phosphate"
#         frequency: 1.0
#       }
#       top_values {
#         value: "desirudin"
#         frequency: 1.0
#       }
#       top_values {
#         value: "calcium polycarbophil"
#         frequency: 1.0
#       }
#       top_values {
#         value: "amiloride hydrocloride"
#         frequency: 1.0
#       }
#       top_values {
#         value: "albuterol sulfate"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Zolpidem tartrate"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Zolpidem Tartrate"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Ziprasidone hydrochloride"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Zinc Oxide"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Willow, Black Salix nigra"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Trimipramine maleate"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Triclosan"
#         frequency: 1.0
#       }
#       avg_length: 32.043479919433594
#       rank_histogram {
#         buckets {
#           label: "DOCUSATE SODIUM"
#           sample_count: 3.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "Trace Elements 4"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "Sodium Fluoride"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 3
#           high_rank: 3
#           label: "Octinoxate and Titanium Dioxide"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 4
#           high_rank: 4
#           label: "topiramate"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 5
#           high_rank: 5
#           label: "robinia pseudoacacia pollen"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 6
#           high_rank: 6
#           label: "prazosin hydrochloride"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 7
#           high_rank: 7
#           label: "leflunomide"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 8
#           high_rank: 8
#           label: "disopyramide phosphate"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 9
#           high_rank: 9
#           label: "desirudin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 10
#           high_rank: 10
#           label: "calcium polycarbophil"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 11
#           high_rank: 11
#           label: "amiloride hydrocloride"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 12
#           high_rank: 12
#           label: "albuterol sulfate"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 13
#           high_rank: 13
#           label: "Zolpidem tartrate"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 14
#           high_rank: 14
#           label: "Zolpidem Tartrate"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 15
#           high_rank: 15
#           label: "Ziprasidone hydrochloride"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 16
#           high_rank: 16
#           label: "Zinc Oxide"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 17
#           high_rank: 17
#           label: "Willow, Black Salix nigra"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 18
#           high_rank: 18
#           label: "Trimipramine maleate"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 19
#           high_rank: 19
#           label: "Triclosan"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 20
#           high_rank: 20
#           label: "Tretinoin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 21
#           high_rank: 21
#           label: "Torsemide"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 22
#           high_rank: 22
#           label: "Titanium Dioxide, Octinoxate, Octisalate, Octocrylene"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 23
#           high_rank: 23
#           label: "TITANIUM DIOXIDE"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 24
#           high_rank: 24
#           label: "Short Ragweed Pollen Allergen Extract"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 25
#           high_rank: 25
#           label: "Sepia comp."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 26
#           high_rank: 26
#           label: "SODIUM FLUORIDE"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 27
#           high_rank: 27
#           label: "Rizatriptan Benzoate"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 28
#           high_rank: 28
#           label: "Progesterone"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 29
#           high_rank: 29
#           label: "Piperacillin Sodium and Tazobactam Sodium"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 30
#           high_rank: 30
#           label: "Phoma"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 31
#           high_rank: 31
#           label: "PYRITHIONE ZINC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 32
#           high_rank: 32
#           label: "PULLULARIA PULLULANS"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 33
#           high_rank: 33
#           label: "Oxymetazoline HCl"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 34
#           high_rank: 34
#           label: "Oxygen"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 35
#           high_rank: 35
#           label: "Octinoxate, Oxybenzone, Titanium Dioxide"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 36
#           high_rank: 36
#           label: "OCTINOXATE, TITANIUM DIOXIDE, OXYBENZONE"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 37
#           high_rank: 37
#           label: "Menthol"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 38
#           high_rank: 38
#           label: "Losartan Potassium"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 39
#           high_rank: 39
#           label: "Lorazepam"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 40
#           high_rank: 40
#           label: "Ibuprofen and Pseudoephedrine Hydrochloride"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 41
#           high_rank: 41
#           label: "Glycerin"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 42
#           high_rank: 42
#           label: "GLYCERIN ALLANTOIN"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 43
#           high_rank: 43
#           label: "Fluconazole"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 44
#           high_rank: 44
#           label: "Escitalopram"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 45
#           high_rank: 45
#           label: "Donepezil Hydrochloride"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 46
#           high_rank: 46
#           label: "Docusate Sodium"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 47
#           high_rank: 47
#           label: "Dextromethorphan, Guaifenesin, Phenylephrine"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 48
#           high_rank: 48
#           label: "Calcium carbonate"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 49
#           high_rank: 49
#           label: "CETYLPYRIDINIUM CHLORIDE and HYDROGEN PEROXIDE"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 50
#           high_rank: 50
#           label: "Brompheniramine maleate, Dextromethorphan HBr, Phenylephrine HCl"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 51
#           high_rank: 51
#           label: "Bismuth Subsalicylate"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 52
#           high_rank: 52
#           label: "Aralia racemosa, Blatta americana, Blatta orientalis, Chelidonium majus, Hydrastis canadensis, Linum usitatissimum, Phosphorus, Sulphur, Trifolium pratense"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 53
#           high_rank: 53
#           label: "Anticoagulant Citrate Phosphate Dextrose (CPD) AND AS-5 Red Cell Preservative"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 54
#           high_rank: 54
#           label: "Alcohol"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 55
#           high_rank: 55
#           label: "Aesculus hippocastanum, Arnica montana, Arsenicum album, Hamamelis virginiana, Helonias dioica, Hepar suis, Iris versicolor, Pancreas suis,"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 56
#           high_rank: 56
#           label: "Adrenalinum, Alfalfa, Ambrosia artemisiaefolia, Anacardium orientale, Argentum nitricum, Avena sativa, Aesculus hippocastanum, flos, Calcarea carbonica, Carboneum oxygenisatum, Carpinus betulus, flos, Citricum acidum, Gelsemium sempervirens, Hypothalamus, Kali phosphoricum, Lecithin, Natrum muriaticum, Olea europaea, flos, Phosphoricum acidum, Pituitarum posterium, Selenium metallicum, Sepia, Silicea, Thyroidinum"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 57
#           high_rank: 57
#           label: "Acetaminophen, Dextromethorphan HBr, Doxylamine succinate"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 58
#           high_rank: 58
#           label: "Acetaminophen, Chlorpheniramine Maleate, Dextromethorphan Hydrobromide, Phenylephrine Hydrochloride"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 59
#           high_rank: 59
#           label: "ARNICA MONTANA"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 60
#           high_rank: 60
#           label: "AP House Dust Mix"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 61
#           high_rank: 61
#           label: "ALUMINUM ZIRCONIUM OCTACHLOROHYDREX GLY"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 62
#           high_rank: 62
#           label: "ALLANTOIN"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 63
#           high_rank: 63
#           label: "ALCOHOL"
#           sample_count: 1.0
#         }
#       }
#     }
#     path {
#       step: "product"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 77
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 77
#       }
#       unique: 67
#       top_values {
#         value: "8/27/2022"
#         frequency: 2.0
#       }
#       top_values {
#         value: "7/3/2022"
#         frequency: 2.0
#       }
#       top_values {
#         value: "7/29/2022"
#         frequency: 2.0
#       }
#       top_values {
#         value: "6/27/2022"
#         frequency: 2.0
#       }
#       top_values {
#         value: "5/7/2022"
#         frequency: 2.0
#       }
#       top_values {
#         value: "5/28/2022"
#         frequency: 2.0
#       }
#       top_values {
#         value: "5/24/2022"
#         frequency: 2.0
#       }
#       top_values {
#         value: "4/24/2022"
#         frequency: 2.0
#       }
#       top_values {
#         value: "10/3/2021"
#         frequency: 2.0
#       }
#       top_values {
#         value: "1/9/2022"
#         frequency: 2.0
#       }
#       top_values {
#         value: "9/7/2021"
#         frequency: 1.0
#       }
#       top_values {
#         value: "9/5/2022"
#         frequency: 1.0
#       }
#       top_values {
#         value: "9/23/2021"
#         frequency: 1.0
#       }
#       top_values {
#         value: "9/22/2021"
#         frequency: 1.0
#       }
#       top_values {
#         value: "9/15/2021"
#         frequency: 1.0
#       }
#       top_values {
#         value: "9/13/2021"
#         frequency: 1.0
#       }
#       top_values {
#         value: "9/1/2022"
#         frequency: 1.0
#       }
#       top_values {
#         value: "8/9/2022"
#         frequency: 1.0
#       }
#       top_values {
#         value: "8/8/2022"
#         frequency: 1.0
#       }
#       top_values {
#         value: "8/4/2022"
#         frequency: 1.0
#       }
#       avg_length: 8.896103858947754
#       rank_histogram {
#         buckets {
#           label: "8/27/2022"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "7/3/2022"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "7/29/2022"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 3
#           high_rank: 3
#           label: "6/27/2022"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 4
#           high_rank: 4
#           label: "5/7/2022"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 5
#           high_rank: 5
#           label: "5/28/2022"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 6
#           high_rank: 6
#           label: "5/24/2022"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 7
#           high_rank: 7
#           label: "4/24/2022"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 8
#           high_rank: 8
#           label: "10/3/2021"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 9
#           high_rank: 9
#           label: "1/9/2022"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 10
#           high_rank: 10
#           label: "9/7/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 11
#           high_rank: 11
#           label: "9/5/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 12
#           high_rank: 12
#           label: "9/23/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 13
#           high_rank: 13
#           label: "9/22/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 14
#           high_rank: 14
#           label: "9/15/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 15
#           high_rank: 15
#           label: "9/13/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 16
#           high_rank: 16
#           label: "9/1/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 17
#           high_rank: 17
#           label: "8/9/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 18
#           high_rank: 18
#           label: "8/8/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 19
#           high_rank: 19
#           label: "8/4/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 20
#           high_rank: 20
#           label: "8/23/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 21
#           high_rank: 21
#           label: "8/22/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 22
#           high_rank: 22
#           label: "8/14/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 23
#           high_rank: 23
#           label: "7/8/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 24
#           high_rank: 24
#           label: "7/28/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 25
#           high_rank: 25
#           label: "7/27/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 26
#           high_rank: 26
#           label: "7/13/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 27
#           high_rank: 27
#           label: "7/12/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 28
#           high_rank: 28
#           label: "6/24/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 29
#           high_rank: 29
#           label: "6/21/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 30
#           high_rank: 30
#           label: "6/20/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 31
#           high_rank: 31
#           label: "6/17/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 32
#           high_rank: 32
#           label: "5/27/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 33
#           high_rank: 33
#           label: "5/14/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 34
#           high_rank: 34
#           label: "5/13/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 35
#           high_rank: 35
#           label: "5/11/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 36
#           high_rank: 36
#           label: "4/5/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 37
#           high_rank: 37
#           label: "4/11/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 38
#           high_rank: 38
#           label: "4/10/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 39
#           high_rank: 39
#           label: "3/9/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 40
#           high_rank: 40
#           label: "3/6/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 41
#           high_rank: 41
#           label: "3/17/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 42
#           high_rank: 42
#           label: "3/12/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 43
#           high_rank: 43
#           label: "12/8/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 44
#           high_rank: 44
#           label: "12/5/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 45
#           high_rank: 45
#           label: "12/4/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 46
#           high_rank: 46
#           label: "12/26/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 47
#           high_rank: 47
#           label: "12/25/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 48
#           high_rank: 48
#           label: "12/12/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 49
#           high_rank: 49
#           label: "11/8/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 50
#           high_rank: 50
#           label: "11/30/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 51
#           high_rank: 51
#           label: "11/21/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 52
#           high_rank: 52
#           label: "11/2/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 53
#           high_rank: 53
#           label: "11/13/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 54
#           high_rank: 54
#           label: "10/25/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 55
#           high_rank: 55
#           label: "10/19/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 56
#           high_rank: 56
#           label: "10/17/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 57
#           high_rank: 57
#           label: "10/15/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 58
#           high_rank: 58
#           label: "10/10/2021"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 59
#           high_rank: 59
#           label: "1/8/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 60
#           high_rank: 60
#           label: "1/27/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 61
#           high_rank: 61
#           label: "1/24/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 62
#           high_rank: 62
#           label: "1/2/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 63
#           high_rank: 63
#           label: "1/19/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 64
#           high_rank: 64
#           label: "1/15/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 65
#           high_rank: 65
#           label: "1/13/2022"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 66
#           high_rank: 66
#           label: "1/1/2022"
#           sample_count: 1.0
#         }
#       }
#     }
#     path {
#       step: "period_key"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 70
#         num_missing: 7
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 70
#       }
#       mean: 9.775714254379272
#       std_dev: 5.475099276519059
#       min: 1.25
#       median: 9.619999885559082
#       max: 19.8799991607666
#       histograms {
#         buckets {
#           low_value: 1.25
#           high_value: 3.11299991607666
#           sample_count: 9.004406222130166
#         }
#         buckets {
#           low_value: 3.11299991607666
#           high_value: 4.97599983215332
#           sample_count: 10.962393662157423
#         }
#         buckets {
#           low_value: 4.97599983215332
#           high_value: 6.8389997482299805
#           sample_count: 3.9993250726054757
#         }
#         buckets {
#           low_value: 6.8389997482299805
#           high_value: 8.70199966430664
#           sample_count: 9.006875056730822
#         }
#         buckets {
#           low_value: 8.70199966430664
#           high_value: 10.5649995803833
#           sample_count: 6.054799783434221
#         }
#         buckets {
#           low_value: 10.5649995803833
#           high_value: 12.427999496459961
#           sample_count: 7.012670756858129
#         }
#         buckets {
#           low_value: 12.427999496459961
#           high_value: 14.290999412536621
#           sample_count: 5.920043277667593
#         }
#         buckets {
#           low_value: 14.290999412536621
#           high_value: 16.15399932861328
#           sample_count: 7.0055415982864195
#         }
#         buckets {
#           low_value: 16.15399932861328
#           high_value: 18.01699924468994
#           sample_count: 5.997444543066014
#         }
#         buckets {
#           low_value: 18.01699924468994
#           high_value: 19.8799991607666
#           sample_count: 5.03650002706374
#         }
#       }
#       histograms {
#         buckets {
#           low_value: 1.25
#           high_value: 2.8399999141693115
#           sample_count: 7.000000000000001
#         }
#         buckets {
#           low_value: 2.8399999141693115
#           high_value: 4.150000095367432
#           sample_count: 7.000000000000001
#         }
#         buckets {
#           low_value: 4.150000095367432
#           high_value: 5.849999904632568
#           sample_count: 7.000000000000001
#         }
#         buckets {
#           low_value: 5.849999904632568
#           high_value: 7.900000095367432
#           sample_count: 7.000000000000001
#         }
#         buckets {
#           low_value: 7.900000095367432
#           high_value: 9.619999885559082
#           sample_count: 7.000000000000001
#         }
#         buckets {
#           low_value: 9.619999885559082
#           high_value: 10.930000305175781
#           sample_count: 7.000000000000001
#         }
#         buckets {
#           low_value: 10.930000305175781
#           high_value: 13.170000076293945
#           sample_count: 7.000000000000001
#         }
#         buckets {
#           low_value: 13.170000076293945
#           high_value: 15.920000076293945
#           sample_count: 7.000000000000001
#         }
#         buckets {
#           low_value: 15.920000076293945
#           high_value: 17.8799991607666
#           sample_count: 7.000000000000001
#         }
#         buckets {
#           low_value: 17.8799991607666
#           high_value: 19.8799991607666
#           sample_count: 7.000000000000001
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "amount"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 77
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 7.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
# ...
#           high_value: 8.970000267028809
#           sample_count: 8.1
#         }
#         buckets {
#           low_value: 8.970000267028809
#           high_value: 10.239999771118164
#           sample_count: 8.1
#         }
#         buckets {
#           low_value: 10.239999771118164
#           high_value: 11.569999694824219
#           sample_count: 8.1
#         }
#         buckets {
#           low_value: 11.569999694824219
#           high_value: 13.930000305175781
#           sample_count: 8.1
#         }
#         buckets {
#           low_value: 13.930000305175781
#           high_value: 16.020000457763672
#           sample_count: 8.1
#         }
#         buckets {
#           low_value: 16.020000457763672
#           high_value: 17.979999542236328
#           sample_count: 8.1
#         }
#         buckets {
#           low_value: 17.979999542236328
#           high_value: 19.8799991607666
#           sample_count: 8.1
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "amount"
#     }
#   }
#   features {
#     type: STRING
#     string_stats {
#       common_stats {
#         num_non_missing: 90
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 9.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 90
#       }
#       unique: 80
#       top_values {
#         value: "Physicians Total Care, Inc."
#         frequency: 4.0
#       }
#       top_values {
#         value: "Wockhardt Limited"
#         frequency: 2.0
#       }
#       top_values {
#         value: "Supervalu Inc"
#         frequency: 2.0
#       }
#       top_values {
#         value: "Nelco Laboratories, Inc."
#         frequency: 2.0
#       }
#       top_values {
#         value: "Jubilant HollisterStier LLC"
#         frequency: 2.0
#       }
#       top_values {
#         value: "Hospira, Inc."
#         frequency: 2.0
#       }
#       top_values {
#         value: "Baxter Healthcare Corporation"
#         frequency: 2.0
#       }
#       top_values {
#         value: "American Regent, Inc."
#         frequency: 2.0
#       }
#       top_values {
#         value: "sanofi-aventis U.S. LLC"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Western Family Foods Inc"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Walgreen Company"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Ventura Corporation LTD"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Uriel Pharmacy Inc."
#         frequency: 1.0
#       }
#       top_values {
#         value: "Unit Dose Services"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Topco Associates LLC"
#         frequency: 1.0
#       }
#       top_values {
#         value: "The Procter & Gamble Manufacturing Company"
#         frequency: 1.0
#       }
#       top_values {
#         value: "The Harvard Drug Group, LLC"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Terumo Corporation"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Target Corporation"
#         frequency: 1.0
#       }
#       top_values {
#         value: "Supervalu Inc."
#         frequency: 1.0
#       }
#       avg_length: 22.9777774810791
#       rank_histogram {
#         buckets {
#           label: "Physicians Total Care, Inc."
#           sample_count: 4.0
#         }
#         buckets {
#           low_rank: 1
#           high_rank: 1
#           label: "Wockhardt Limited"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 2
#           high_rank: 2
#           label: "Supervalu Inc"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 3
#           high_rank: 3
#           label: "Nelco Laboratories, Inc."
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 4
#           high_rank: 4
#           label: "Jubilant HollisterStier LLC"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 5
#           high_rank: 5
#           label: "Hospira, Inc."
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 6
#           high_rank: 6
#           label: "Baxter Healthcare Corporation"
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 7
#           high_rank: 7
#           label: "American Regent, Inc."
#           sample_count: 2.0
#         }
#         buckets {
#           low_rank: 8
#           high_rank: 8
#           label: "sanofi-aventis U.S. LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 9
#           high_rank: 9
#           label: "Western Family Foods Inc"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 10
#           high_rank: 10
#           label: "Walgreen Company"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 11
#           high_rank: 11
#           label: "Ventura Corporation LTD"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 12
#           high_rank: 12
#           label: "Uriel Pharmacy Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 13
#           high_rank: 13
#           label: "Unit Dose Services"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 14
#           high_rank: 14
#           label: "Topco Associates LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 15
#           high_rank: 15
#           label: "The Procter & Gamble Manufacturing Company"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 16
#           high_rank: 16
#           label: "The Harvard Drug Group, LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 17
#           high_rank: 17
#           label: "Terumo Corporation"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 18
#           high_rank: 18
#           label: "Target Corporation"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 19
#           high_rank: 19
#           label: "Supervalu Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 20
#           high_rank: 20
#           label: "Speer Laboratories, LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 21
#           high_rank: 21
#           label: "Shopko Stores Operating Co., LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 22
#           high_rank: 22
#           label: "Shanghai Yinjing Medical Supplies Co., Ltd."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 23
#           high_rank: 23
#           label: "Sage Products LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 24
#           high_rank: 24
#           label: "Safeway, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 25
#           high_rank: 25
#           label: "Safeway Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 26
#           high_rank: 26
#           label: "SMART SENSE (Kmart)"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 27
#           high_rank: 27
#           label: "SHISEIDO AMERICAS CORPORATION"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 28
#           high_rank: 28
#           label: "SDA Laboratories, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 29
#           high_rank: 29
#           label: "Rebel Distributors Corp."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 30
#           high_rank: 30
#           label: "Qualitest Pharmaceuticals"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 31
#           high_rank: 31
#           label: "Proficient Rx LP"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 32
#           high_rank: 32
#           label: "Procter and Gamble Manufacturing Company"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 33
#           high_rank: 33
#           label: "Procter & Gamble Manufacturing Company"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 34
#           high_rank: 34
#           label: "Preferred Pharmaceuticals, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 35
#           high_rank: 35
#           label: "Preferred Pharmaceuticals, Inc"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 36
#           high_rank: 36
#           label: "Pfizer Laboratories Div Pfizer Inc"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 37
#           high_rank: 37
#           label: "Performance Health LLC."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 38
#           high_rank: 38
#           label: "Parfums Christian Dior"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 39
#           high_rank: 39
#           label: "Paddock Laboratories, LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 40
#           high_rank: 40
#           label: "PETNET Solutions, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 41
#           high_rank: 41
#           label: "OMP, INC."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 42
#           high_rank: 42
#           label: "Native Remedies, LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 43
#           high_rank: 43
#           label: "Modern Welding Company, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 44
#           high_rank: 44
#           label: "MineralHouse Corporation"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 45
#           high_rank: 45
#           label: "Merck Sharp & Dohme Corp."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 46
#           high_rank: 46
#           label: "MedVantx, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 47
#           high_rank: 47
#           label: "Marathon Pharmaceuticals, LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 48
#           high_rank: 48
#           label: "Laboratoires Boiron"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 49
#           high_rank: 49
#           label: "L\'Oreal USA Products Inc"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 50
#           high_rank: 50
#           label: "KAISER FOUNDATION HOSPITALS"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 51
#           high_rank: 51
#           label: "Janssen Pharmaceuticals, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 52
#           high_rank: 52
#           label: "JAFRA COSMETICS INTERNATIONAL"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 53
#           high_rank: 53
#           label: "Inel Cosmetics Co., Ltd."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 54
#           high_rank: 54
#           label: "Have and Be Co., Ltd."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 55
#           high_rank: 55
#           label: "GOJO Industries, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 56
#           high_rank: 56
#           label: "G.D. Searle LLC Division of Pfizer Inc"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 57
#           high_rank: 57
#           label: "Ferring Pharmaceuticals Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 58
#           high_rank: 58
#           label: "Dr. Reddy\'s Laboratories Limited"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 59
#           high_rank: 59
#           label: "DZA Brands LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 60
#           high_rank: 60
#           label: "Core Brands, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 61
#           high_rank: 61
#           label: "Clinical Solutions Wholesale"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 62
#           high_rank: 62
#           label: "Claris Lifesciences Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 63
#           high_rank: 63
#           label: "Chattem, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 64
#           high_rank: 64
#           label: "CareFusion 213 LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 65
#           high_rank: 65
#           label: "Cardinal Health"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 66
#           high_rank: 66
#           label: "Camber Pharmaceuticals, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 67
#           high_rank: 67
#           label: "CVS Pharmacy"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 68
#           high_rank: 68
#           label: "Bryant Ranch Prepack"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 69
#           high_rank: 69
#           label: "B. Braun Medical Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 70
#           high_rank: 70
#           label: "Aurobindo Pharma Limited"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 71
#           high_rank: 71
#           label: "AuroMedics Pharma LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 72
#           high_rank: 72
#           label: "Arbonne International, LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 73
#           high_rank: 73
#           label: "Apotheca Company"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 74
#           high_rank: 74
#           label: "Antigen Laboratories, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 75
#           high_rank: 75
#           label: "Allergy Laboratories, Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 76
#           high_rank: 76
#           label: "Ajou Medics Co., Ltd"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 77
#           high_rank: 77
#           label: "Aidarex Pharmaceuticals LLC"
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 78
#           high_rank: 78
#           label: "Actavis Inc."
#           sample_count: 1.0
#         }
#         buckets {
#           low_rank: 79
#           high_rank: 79
#           label: "AMI Cosmetic Co.,Ltd."
#           sample_count: 1.0
#         }
#       }
#     }
#     path {
#       step: "supplier"
#     }
#   }
# }

# %%
training_schema_fixed = tfdv.load_schema_text('training_schema_fixed')
anomalies = tfdv.validate_statistics(statistics = training_stats, schema = training_schema_fixed)
tfdv.display_anomalies(anomalies)
# print(training_stats)
# anomaly_info = MessageToDict(anomalies)
# anomaly_info.keys()
# Out:
#              Anomaly short description  \
# Feature name
# 'city'                  Column dropped
# 'product'               Invalid values
# 'id'               Out-of-range values
#
#                                                                                              Anomaly long description
# Feature name
# 'city'        The feature was present in fewer examples than expected: minimum fraction = 0.990000, actual = 0.970000
# 'product'                                      String values that were not ints were found, such as "Absolut Citron".
# 'id'                                                                                  Unexpectedly large value: 1000.

# %% [markdown]
# ### Update the features
